# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'DataGabungan.xlsx')

# %%
temp = df[['title','url']]

# %%
temp = temp.rename(columns={"url": "URL"})

# %%
SKU_R = pd.read_csv('SKU_R.csv', header =[0])
SKU_Python = pd.read_csv('SKU_Python.csv', header =[0])

# %%
SKU_Python = pd.read_excel(r'Perbandingan Mapping  Python.xlsx', sheet_name='SKU_Python baru')

# %%
SKU_Python
# Out:
#        Unnamed: 0                  SKU  \
# 0               0  TP-LINK Archer AX10
# 1               1  TP-LINK Archer AX10
# 2               2  TP-LINK Archer AX10
# 3               3  TP-LINK Archer AX10
# 4               4  TP-LINK Archer AX10
# ...           ...                  ...
# 20995       20995    TP-LINK TL-UE300C
# 20996       20996    TP-LINK TL-UE300C
# 20997       20997    TP-LINK TL-UE300C
# 20998       20998    TP-LINK TL-UE300C
# 20999       20999    TP-LINK TL-UE300C
#
#                                                      url
# 0      https://shopee.co.id/Tp-Link-Archer-AX10-AX150...
# 1      https://shopee.co.id/TP-LINK-Archer-AX10-AX150...
# 2      https://shopee.co.id/TP-Link-Archer-AX10-AX150...
# 3      https://shopee.co.id/TP-Link-Archer-AX10-AX150...
# 4      https://shopee.co.id/Tp-link-Archer-AX10-AX150...
# ...                                                  ...
# 20995  https://www.lazada.co.id/products/diskon-tp-li...
# ...

# %%
#SKU_R = SKU_R.drop(['Unnamed: 0'], axis=1)
SKU_Python = SKU_Python.drop(['Unnamed: 0'], axis=1)

# %%
SKU_Python = SKU_Python.rename(columns={"SKU": "SKU Python"})
SKU_Python = SKU_Python.rename(columns={"url": "URL"})
#SKU_R = SKU_R.rename(columns={"SKU": "SKU R"})

# %%
#SKU_Python = SKU_Python.sort_values(by=['SKU Python', 'URL']).reset_index(drop=True)
SKU_R = SKU_R.sort_values(by=['SKU R']).reset_index(drop=True)

# %%
SKU_R
# Out:
#                      SKU R                                                URL
# 0      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-ax15...
# 1      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-tpli...
# 2      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-ax15...
# 3      TP-LINK Archer AX10  https://www.lazada.co.id/products/bisa-cod-tp-...
# 4      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-arch...
# ...                    ...                                                ...
# 21003    TP-LINK Tapo P100  https://www.tokopedia.com/exadayalokaniaga/tp-...
# 21004    TP-LINK Tapo P100  https://www.tokopedia.com/rajaitofficial/tp-li...
# 21005    TP-LINK Tapo P100  https://www.tokopedia.com/intisukses/tp-link-t...
# 21006    TP-LINK Tapo P100  https://www.lazada.co.id/products/tp-link-tapo...
# 21007    TP-LINK Tapo P100  https://www.lazada.co.id/products/promo-murah-...
#
# [21008 rows x 2 columns]

# %%
#SKU_Python = SKU_Python.sort_values(by=['URL', 'SKU Python'])
#SKU_R = SKU_R.sort_values(by=['URL', 'SKU R'])

# %%
SKU_Python.dropna(subset = ["URL"], inplace=True)

# %%
#SKU_R = SKU_R.sort_values(by=['SKU R']).reset_index(drop=True)
#SKU_Python = SKU_Python.sort_values(by=['SKU Python']).reset_index(drop=True)

# %%
SKU_R
# Out:
#                      SKU R                                                URL
# 0      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-ax15...
# 1      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-tpli...
# 2      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-ax15...
# 3      TP-LINK Archer AX10  https://www.lazada.co.id/products/bisa-cod-tp-...
# 4      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-arch...
# ...                    ...                                                ...
# 21003    TP-LINK Tapo P100  https://www.tokopedia.com/exadayalokaniaga/tp-...
# 21004    TP-LINK Tapo P100  https://www.tokopedia.com/rajaitofficial/tp-li...
# 21005    TP-LINK Tapo P100  https://www.tokopedia.com/intisukses/tp-link-t...
# 21006    TP-LINK Tapo P100  https://www.lazada.co.id/products/tp-link-tapo...
# 21007    TP-LINK Tapo P100  https://www.lazada.co.id/products/promo-murah-...
#
# [21008 rows x 2 columns]

# %%
#Outer Join 
GabunganSKU_0 = pd.merge(SKU_R,SKU_Python,on='URL',how='left')

# %%
#Left Join 
GabunganSKU = pd.merge(GabunganSKU_0,temp,on='URL',how='left')

# %%
GabunganSKU_0
# Out:
#                      SKU R                                                URL  \
# 0      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-ax15...
# 1      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-tpli...
# 2      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-ax15...
# 3      TP-LINK Archer AX10  https://www.lazada.co.id/products/bisa-cod-tp-...
# 4      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-arch...
# ...                    ...                                                ...
# 21333    TP-LINK Tapo P100  https://www.tokopedia.com/exadayalokaniaga/tp-...
# 21334    TP-LINK Tapo P100  https://www.tokopedia.com/rajaitofficial/tp-li...
# 21335    TP-LINK Tapo P100  https://www.tokopedia.com/intisukses/tp-link-t...
# 21336    TP-LINK Tapo P100  https://www.lazada.co.id/products/tp-link-tapo...
# 21337    TP-LINK Tapo P100  https://www.lazada.co.id/products/promo-murah-...
#
#                 SKU Python
# ...

# %%
#list_SKU_R = GabunganSKU['SKU R'].unique().tolist()
list_SKU_P = GabunganSKU['SKU Python'].unique().tolist()

# %%
GabunganSKU.to_csv(r'GabunganSKU_Fix.csv')

# %%
#GabunganSKU = GabunganSKU.rename(columns={"TP-LINK Archer-C24": "TP-LINK Archer C24"})
GabunganSKU["SKU Python"] = GabunganSKU["SKU Python"].replace("TP-LINK Archer-C24", "TP-LINK Archer C24")
GabunganSKU["SKU Python"] = GabunganSKU["SKU Python"].replace("TP-LINK Archer-C54", "TP-LINK Archer C54")

# %%
GabunganSKU.to_csv(r'GabunganSKU_Fix.csv')

# %%
GabunganSKU
# Out:
#                      SKU R                                                URL  \
# 0      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-ax15...
# 1      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-tpli...
# 2      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-ax15...
# 3      TP-LINK Archer AX10  https://www.lazada.co.id/products/bisa-cod-tp-...
# 4      TP-LINK Archer AX10  https://www.lazada.co.id/products/tp-link-arch...
# ...                    ...                                                ...
# 21335    TP-LINK Tapo P100  https://www.tokopedia.com/intisukses/tp-link-t...
# 21336    TP-LINK Tapo P100  https://www.lazada.co.id/products/tp-link-tapo...
# 21337    TP-LINK Tapo P100  https://www.lazada.co.id/products/promo-murah-...
# 21338                  NaN  https://shopee.co.id/88888888-TP-LINK-archer-C...
# 21339                  NaN  https://www.lazada.co.id/products/tp-link-arch...
#
# ...
